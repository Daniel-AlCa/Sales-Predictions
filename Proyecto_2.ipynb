# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-AlCa/Sales-Predictions/blob/main/Proyecto_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Dataset Opcion 1
import pandas as pd

#1) Fuente de datos: Kaggle

filename =('/content/drive/MyDrive/Coding Dojo/Codificación de Coding Dojo/Proyecto 2/Mall_Customers.csv')
df=pd.read_csv(filename)
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# 2) Breve descripción de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
# 3) ¿Cuál es el objetivo?

#El objetivo seriaclasificar el spending score, dividiendo el spending score en rangos de 1-33 : LOW , de 34 a 66 : Medium, de 67-100: High

#4) ¿Este es un problema de clasificación o regresión?

#Una vez transformada la columna seria un problema de clasificación de 3 variables

#5) ¿Cuántas características hay?

#hay 3 caracteristicas

#6) ¿Cuántas filas de datos hay?

#200 filas

#7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos?

#el reto seria hacer la clasificación 3 variable y convertir la fila de Spending score en una fila Ordinal con 3 valores, par adespues utilizar el one hot encoder para realizar la clasificacíon

# %%
#Dataset opcion 2

#1) Fuente de datos: Kaggle
import pandas as pd
filename1 =('/content/drive/MyDrive/Coding Dojo/Codificación de Coding Dojo/Proyecto 2/winequality-white.xlsx')
df1=pd.read_excel(filename1)
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
# 2) Breve descripción de datos
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# 3) ¿Cuál es el objetivo?

#El objetivo seriaclasificar la calidad el vino la cual tiene numeros de 3-9, podria enfocarme solo en la categoría 9 o hacer una clasificación muy amplia con 7 valores

#4) ¿Este es un problema de clasificación o regresión?

#Una vez transformada la columna seria un problema de clasificación de 2 o 7 variables

#5) ¿Cuántas características hay?

#hay 12 caracteristicas

#6) ¿Cuántas filas de datos hay?

#4898 filas

#7) ¿Qué retos, si es que hay alguno, prevén en la limpieza, exploración o modelización con este conjunto de datos?

#el reto seria hacer la clasificación de 2 o 7 variable y convertir la fila objetivo en varias posibles columans dependiendo de como se vaya a clasificar

# %%
#Semana 2
  #Se trabajara con lso datos de la calidad del vino:

# -eliminado las columnas innecesarias
    #No hay columnas innecesarias

# -eliminado las filas duplicadas

df1.duplicated().sum() # hay 937 filas duplicadas
df1=df1.drop_duplicates()
df1.duplicated().sum() #hay 0 filas duplicadas

#-identificado y abordado los valores faltantes

    #No hay datos Nan
  
#-identificado y corregido las inconsistencias en los datos para los valores categóricos (es decir, Cat, cat, cats)

    #Todos los datos son numeros enteros o con decimales
# Out:
# 0

# %%
#-producido visuales univariantes para el objetivo y todas las características

df1.hist(figsize=(10,10));

# %%
#-identificado los valores atípicos
df1.info()
#pd.set_option("display.max_rows",None)
#pd.reset_option("all")
df1['quality'].value_counts()
#se revisaron los valores de cada colimna y no se dientificaron valores atípicos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3961 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3961 non-null   float64
#  1   volatile acidity      3961 non-null   float64
#  2   citric acid           3961 non-null   float64
#  3   residual sugar        3961 non-null   float64
#  4   chlorides             3961 non-null   float64
#  5   free sulfur dioxide   3961 non-null   float64
#  6   total sulfur dioxide  3961 non-null   float64
#  7   density               3961 non-null   float64
#  8   pH                    3961 non-null   float64
#  9   sulphates             3961 non-null   float64
#  10  alcohol               3961 non-null   float64
#  11  quality               3961 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 402.3 KB
# 6    1788
# 5    1175
# 7     689
# 4     153
# 8     131
# 3      20
# 9       5
# ...

# %%
# producido un mapa de calor de correlación e identificado cualquier correlaciones moderadas o
# fuertes entre el objetivo y las características y/o entre una característica y otra
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

corr = df1.corr(numeric_only=True)
corr
import seaborn as sns

sns.heatmap(corr, cmap = 'Oranges', annot = True);

plt.title("Heat Map",fontsize = 10);

print('Se aprecia que la columna con mayor relación a la calidad es el alcohol')
# Out:
# Se aprecia que la columna con mayor relación a la calidad es el alcohol
